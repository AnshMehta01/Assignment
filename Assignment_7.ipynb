# %%
# Q1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(102317259)

# %%
# Part I
sales_data = np.random.randint(1000, 5001, size=(12, 4))
columns = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

df = pd.DataFrame(sales_data, columns=columns, index=months)
print(df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4582      3424            4696    4351
# Feb         2150      3453            4825    3918
# Mar         3448      4230            3252    4400
# Apr         3500      4327            1596    1439
# May         3394      2712            3506    2333
# Jun         3282      4089            1549    2779
# Jul         2303      2480            1963    3654
# Aug         3517      2152            3892    4922
# Sep         2535      4078            3153    4476
# Oct         1547      4083            1311    3245
# Nov         4591      2131            1722    3778
# Dec         1974      1538            4361    4354

# %%
# Part II
print("First 5 rows:\n", df.head())
print("\nSummary Statistics:\n", df.describe())
# Out:
# First 5 rows:
#       Electronics  Clothing  Home & Kitchen  Sports
# Jan         4582      3424            4696    4351
# Feb         2150      3453            4825    3918
# Mar         3448      4230            3252    4400
# Apr         3500      4327            1596    1439
# May         3394      2712            3506    2333
#
# Summary Statistics:
#         Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3068.583333  3224.750000     2985.500000  3637.416667
# std     977.879567   978.803084     1308.484307  1021.664280
# min    1547.000000  1538.000000     1311.000000  1439.000000
# 25%    2264.750000  2398.000000     1690.500000  3128.500000
# 50%    3338.000000  3438.500000     3202.500000  3848.000000
# 75%    3504.250000  4084.500000     4009.250000  4365.500000
# max    4591.000000  4327.000000     4825.000000  4922.000000

# %%
totalSalesCategory = df.sum()
print("\nTotal Sales per Category:\n", totalSalesCategory)
# Out:
# Total Sales per Category:
#  Electronics       36823
# Clothing          38697
# Home & Kitchen    35826
# Sports            43649
# dtype: int64

# %%
df["Total Sales"] = df.sum(axis=1)
df["Growth Rate"] = df["Total Sales"].pct_change() * 100

roll_number = 102317156
if roll_number % 2 == 0:
    df["Electronics"] *= 0.9
else:
    df["Clothing"] *= 0.85

print(df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       4123.8      3424            4696    4351        17053          NaN
# Feb       1935.0      3453            4825    3918        14346   -15.874040
# Mar       3103.2      4230            3252    4400        15330     6.859055
# Apr       3150.0      4327            1596    1439        10862   -29.145466
# May       3054.6      2712            3506    2333        11945     9.970539
# Jun       2953.8      4089            1549    2779        11699    -2.059439
# Jul       2072.7      2480            1963    3654        10400   -11.103513
# Aug       3165.3      2152            3892    4922        14483    39.259615
# Sep       2281.5      4078            3153    4476        14242    -1.664020
# Oct       1392.3      4083            1311    3245        10186   -28.479146
# Nov       4131.9      2131            1722    3778        12222    19.988219
# Dec       1776.6      1538            4361    4354        12227     0.040910

# %%
# Part III:
plt.figure(figsize=(10, 6))
sns.lineplot(data=df[columns])
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales Units")
plt.legend(columns)
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(data=df[columns])
plt.title("Sales Distribution by Category")
plt.show()

# %%
import numpy as np

array = np.array([[1, -2, 3], [-4, 5, -6]])
flatArray = array.flatten()
absoluteValues = np.abs(array)
percentilesFlattened = np.percentile(flatArray, [25, 50, 75])
percentilesColumns = np.percentile(array, [25, 50, 75], axis=0)
percentilesRows = np.percentile(array, [25, 50, 75], axis=1)

meanFlattened = np.mean(flatArray)
meanColumns = np.mean(array, axis=0)
meanRows = np.mean(array, axis=1)

medianFlattened = np.median(flatArray)
medianColumns = np.median(array, axis=0)
medianRows = np.median(array, axis=1)

stdFlattened = np.std(flatArray)
stdColumns = np.std(array, axis=0)
stdRows = np.std(array, axis=1)

print("Absolute Values:\n", absoluteValues)
print("Percentiles (Flattened):\n", percentilesFlattened)
print("Percentiles (Columns):\n", percentilesColumns)
print("Percentiles (Rows):\n", percentilesRows)

print("Mean (Flattened):\n", meanFlattened)
print("Mean (Columns):\n", meanColumns)
print("Mean (Rows):\n", meanRows)

print("Median (Flattened):\n", medianFlattened)
print("Median (Columns):\n", medianColumns)
print("Median (Rows):\n", medianRows)

print("Standard Deviation (Flattened):\n", stdFlattened)
print("Standard Deviation (Columns):\n", stdColumns)
print("Standard Deviation (Rows):\n", stdRows)
# Out:
# Absolute Values:
#  [[1 2 3]
#  [4 5 6]]
# Percentiles (Flattened):
#  [-3.5 -0.5  2.5]
# Percentiles (Columns):
#  [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# Percentiles (Rows):
#  [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# Mean (Flattened):
#  -0.5
# Mean (Columns):
#  [-1.5  1.5 -1.5]
# Mean (Rows):
#  [ 0.66666667 -1.66666667]
# Median (Flattened):
#  -0.5
# Median (Columns):
#  [-1.5  1.5 -1.5]
# Median (Rows):
#  [ 1. -4.]
# Standard Deviation (Flattened):
#  3.8622100754188224
# Standard Deviation (Columns):
#  [2.5 3.5 4.5]
# Standard Deviation (Rows):
#  [2.05480467 4.78423336]

# %%
# Q3
import numpy as np
arr = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print("Floor:", np.floor(arr))
print("Ceiling:", np.ceil(arr))
print("Rounded:", np.round(arr))
print("Truncated:", np.trunc(arr))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]

# %%
# Q4
lst = [1, 2, 3, 4, 5]
print("List before swapping:", lst)
temp = lst[1]
lst[1] = lst[3]
lst[3] = temp
print("List after swapping:", lst)
# Out:
# List before swapping: [1, 2, 3, 4, 5]
# List after swapping: [1, 4, 3, 2, 5]

# %%
# Q5
s = {10, 20, 30, 40, 50}
print("Set before swapping:", s)
s_list = list(s)
s_list[1], s_list[3] = s_list[3], s_list[1]
s = set(s_list)
print("Set after swapping:", s)
# Out:
# Set before swapping: {50, 20, 40, 10, 30}
# Set after swapping: {40, 10, 50, 20, 30}
